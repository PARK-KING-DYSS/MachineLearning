# %%
pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="omuIheE81rZpDLFZJcNC")
project = rf.workspace().project("license-plate-recognition-rxg4e")
model = project.version(4).model

# infer on a local image
print(model.predict("/content/2.jpeg", confidence=40, overlap=30).json())

# visualize your prediction
model.predict("/content/2.jpeg", confidence=40, overlap=30).save("prediction.jpg")

# infer on an image hosted elsewhere
# print(model.predict("URL_OF_YOUR_IMAGE", hosted=True, confidence=40, overlap=30).json())
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# {'predictions': [{'x': 234, 'y': 589, 'width': 148, 'height': 61, 'confidence': 0.6898752450942993, 'class': 'License_Plate', 'class_id': 0, 'image_path': '/content/2.jpeg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '780', 'height': '1040'}}

# %%
from google.colab.patches import cv2_imshow
import cv2 as cv
#Replace cv2.imshow() to cv2_imshow()
img = cv.imread('/content/prediction.jpg') #mentioning a path of an image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=576x1024>
